# %% [markdown]
# <a href="https://colab.research.google.com/github/drshn-k/201-assign1/blob/main/Assignment_no_1_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
temp = pd.read_csv("E:/ML_FDP_Program/DSBDA Lab/FODS Assignment 1/iris.csv")
print(temp.index)
# Out:
# RangeIndex(start=0, stop=150, step=1)

# %%
print(temp.columns)
print(temp.shape)
temp.info()
# Out:
# Index(['sepal.length', 'sepal.width', 'petal.length', 'petal.width',
#        'species'],
#       dtype='object')
# (150, 5)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal.length  150 non-null    float64
#  1   sepal.width   150 non-null    float64
#  2   petal.length  150 non-null    float64
#  3   petal.width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
print(temp.head())
# Out:
#    sepal.length  sepal.width  petal.length  petal.width species
# 0           5.1          3.5           1.4          0.2  Setosa
# 1           4.9          3.0           1.4          0.2  Setosa
# 2           4.7          3.2           1.3          0.2  Setosa
# 3           4.6          3.1           1.5          0.2  Setosa
# 4           5.0          3.6           1.4          0.2  Setosa

# %%
print(temp.tail())
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    species
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica

# %%
# to know unique values 
temp.nunique()
# Out:
# sepal.length    35
# sepal.width     23
# petal.length    43
# petal.width     22
# species          3
# dtype: int64

# %%
temp.isna().sum()
# Out:
# sepal.length    0
# sepal.width     0
# petal.length    0
# petal.width     0
# species         0
# dtype: int64

# %%
temp.isnull().sum()
# Out:
# sepal.length    0
# sepal.width     0
# petal.length    0
# petal.width     0
# species         0
# dtype: int64

# %%
print(temp.describe())
# Out:
#        sepal.length  sepal.width  petal.length  petal.width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
#Measure of central tendency
print(temp.mean())
print(temp.median())
print(temp.mode())
print(temp['sepal.length'].mean())
print(temp['sepal.length'].median())
print(temp['sepal.length'].mode())
# Out:
# sepal.length    5.843333
# sepal.width     3.057333
# petal.length    3.758000
# petal.width     1.199333
# dtype: float64
# sepal.length    5.80
# sepal.width     3.00
# petal.length    4.35
# petal.width     1.30
# dtype: float64
#    sepal.length  sepal.width  petal.length  petal.width     species
# 0           5.0          3.0           1.4          0.2      Setosa
# 1           NaN          NaN           1.5          NaN  Versicolor
# 2           NaN          NaN           NaN          NaN   Virginica
# 5.843333333333334
# 5.8
# 0    5.0
# dtype: float64

# %%
#Measure of Variability
print(temp['sepal.length'].var())
print(temp['sepal.length'].std())

# mean (average) absolute deviation
print(temp['sepal.length'].mad())

#range
range1 = max(temp['sepal.length'])-min(temp['sepal.length'])
print(range1)

#IQR
Q1 = np.percentile(temp['sepal.length'], 25)
Q3 = np.percentile(temp['sepal.length'], 75)
print(Q1, Q3)
IQR = Q3 - Q1
print(IQR)
# Out:
# 0.6856935123042507
# 0.828066127977863
# 0.6875555555555557
# 3.6000000000000005
# 5.1 6.4
# 1.3000000000000007

# %%
#Measure of frequency destribution
unique, counts = np.unique(temp['sepal.length'], return_counts=True)
print(unique, counts)
# Out:
# [4.3 4.4 4.5 4.6 4.7 4.8 4.9 5.  5.1 5.2 5.3 5.4 5.5 5.6 5.7 5.8 5.9 6.
#  6.1 6.2 6.3 6.4 6.5 6.6 6.7 6.8 6.9 7.  7.1 7.2 7.3 7.4 7.6 7.7 7.9] [ 1  3  1  4  2  5  6 10  9  4  1  6  7  6  8  7  3  6  6  4  9  7  5  2
#   8  3  4  1  1  3  1  1  1  4  1]

# %%
matrix = np.corrcoef(temp['sepal.length'], temp['sepal.width'])
print(matrix)
print('\n\n')
print(temp[['sepal.length', 'sepal.width']].corr())
# Out:
# [[ 1.         -0.11756978]
#  [-0.11756978  1.        ]]
#
#
#
#               sepal.length  sepal.width
# sepal.length       1.00000     -0.11757
# sepal.width       -0.11757      1.00000

# %%
matrix = temp.corr()
print(matrix)
# Out:
#               sepal.length  sepal.width  petal.length  petal.width
# sepal.length      1.000000    -0.117570      0.871754     0.817941
# sepal.width      -0.117570     1.000000     -0.428440    -0.366126
# petal.length      0.871754    -0.428440      1.000000     0.962865
# petal.width       0.817941    -0.366126      0.962865     1.000000

# %%
import seaborn as sns
sns.pairplot(temp)

# %%
import seaborn as sns
print(temp[temp['species']=='Setosa'].corr())
sns.pairplot(temp[temp['species']=='Setosa'])
# Out:
#               sepal.length  sepal.width  petal.length  petal.width
# sepal.length      1.000000     0.742547      0.267176     0.278098
# sepal.width       0.742547     1.000000      0.177700     0.232752
# petal.length      0.267176     0.177700      1.000000     0.331630
# petal.width       0.278098     0.232752      0.331630     1.000000

# %%
import matplotlib.pyplot as plt
bxplt = sns.boxplot(temp['sepal.width'])
plt.show()
# Out:
# E:\Anaconda\envs\FDP ML\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
Q1 = np.percentile(temp['sepal.width'], 25.) # 25th percentile of the data of the given feature
Q3 = np.percentile(temp['sepal.width'], 75.) # 75th percentile of the data of the given feature
IQR = Q3-Q1 #Interquartile Range
#outlier_step = IQR * 1.5 #That's we were talking about above
#outliers = feature_data[~((feature_data >= Q1 - outlier_step) & (feature_data <= Q3 + outlier_step))].index.tolist()
ll = Q1 - (1.5*IQR)
ul = Q3 + (1.5*IQR)
upper_outliers = temp[temp['sepal.width'] > ul].index.tolist()
lower_outliers = temp[temp['sepal.width'] < ll].index.tolist()
bad_indices = list(set(upper_outliers + lower_outliers))
drop = True
#if not drop:
    #print('For the feature {}, No of Outliers is {}'.format(temp['sepal.width'], len(bad_indices)))
if drop:
    temp.drop(bad_indices, inplace = True, errors = 'ignore')
    print('Outliers from {} feature removed'.format(temp['sepal.width']))
# Out:
# Outliers from 0      3.5
# 1      3.0
# 2      3.2
# 3      3.1
# 4      3.6
#       ...
# 145    3.0
# 146    2.5
# 147    3.0
# 148    3.4
# 149    3.0
# Name: sepal.width, Length: 146, dtype: float64 feature removed

# %%
bxplt = sns.boxplot(temp['sepal.width'])
plt.show()
# Out:
# E:\Anaconda\envs\FDP ML\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
